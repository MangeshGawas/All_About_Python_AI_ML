# %% [markdown]
# <a href="https://colab.research.google.com/github/MangeshGawas/PythonDSA/blob/main/Tensorflow_3(Linear_Regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
X = np.random.rand(100,1)
y = 4+3 * X + np.random.randn(100,1)

# %% [markdown]
# Define the Linear Regression model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1,input_shape=(1,))
])

# %%
model.compile(optimizer='sgd', loss='mse')

# %%
history = model.fit(X,y,epochs=20,verbose=0)

# %%
plt.plot(history.history['loss'])
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
y_pred = model.predict(X)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
plt.scatter(X,y,label="Data")
plt.plot(X,y_pred,color='red',label='Linear Regression')
plt.title("Linear Regression")
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
